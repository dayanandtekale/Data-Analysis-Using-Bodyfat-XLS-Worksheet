# %%
import pandas as pd

# %%
df=pd.read_csv("Bodyfat.csv")

# %%
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
#Summary Function:

# %%
df.head()
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.head().T
# Out:
#                 0         1         2         3        4
# Density    1.0708    1.0853    1.0414    1.0751    1.034
# bodyfat   12.3000    6.1000   25.3000   10.4000   28.700
# Age       23.0000   22.0000   22.0000   26.0000   24.000
# Weight   154.2500  173.2500  154.0000  184.7500  184.250
# Height    67.7500   72.2500   66.2500   72.2500   71.250
# Neck      36.2000   38.5000   34.0000   37.4000   34.400
# Chest     93.1000   93.6000   95.8000  101.8000   97.300
# Abdomen   85.2000   83.0000   87.9000   86.4000  100.000
# Hip       94.5000   98.7000   99.2000  101.2000  101.900
# Thigh     59.0000   58.7000   59.6000   60.1000   63.200
# Knee      37.3000   37.3000   38.9000   37.3000   42.200
# Ankle     21.9000   23.4000   24.0000   22.8000   24.000
# Biceps    32.0000   30.5000   28.8000   32.4000   32.200
# Forearm   27.4000   28.9000   25.2000   29.4000   27.700
# Wrist     17.1000   18.2000   16.6000   18.2000   17.700

# %%
df.head(15)
# Out:
#     Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0    1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1    1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2    1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3    1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4    1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5    1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6    1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7    1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8    1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9    1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
# 10   1.0830      7.1   26  186.25   74.50  38.5  101.5     83.6   98.2   59.7
# ...

# %%
df.tail()
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9

# %%
df.tail(8)
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 244   1.0334     29.0   67  199.50   68.50  40.7  118.3    106.1  101.6
# 245   1.0641     15.2   68  155.50   69.25  36.3   97.4     84.3   94.4
# 246   1.0308     30.2   69  215.50   70.50  40.8  113.7    107.6  110.0
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 244   58.2  38.8   24.1    32.1     29.3   18.5
# 245   54.3  37.5   22.6    29.2     27.3   18.5
# 246   63.3  44.0   22.6    37.5     32.6   18.8
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# ...

# %%
df.shape
# Out:
# (252, 15)

# %%
df.columns
# Out:
# Index(['Density', 'bodyfat', 'Age', 'Weight', 'Height', 'Neck', 'Chest',
#        'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
#        'Wrist'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   bodyfat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Density']
# Out:
# 0      1.0708
# 1      1.0853
# 2      1.0414
# 3      1.0751
# 4      1.0340
#         ...
# 247    1.0736
# 248    1.0236
# 249    1.0328
# 250    1.0399
# 251    1.0271
# Name: Density, Length: 252, dtype: float64

# %%
type(df['Density'])
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# 0      23
# 1      22
# 2      22
# 3      26
# 4      24
#        ..
# 247    70
# 248    72
# 249    72
# 250    72
# 251    74
# Name: Age, Length: 252, dtype: int64

# %%
df[['Density','Age']]
# Out:
#      Density  Age
# 0     1.0708   23
# 1     1.0853   22
# 2     1.0414   22
# 3     1.0751   26
# 4     1.0340   24
# ..       ...  ...
# 247   1.0736   70
# 248   1.0236   72
# 249   1.0328   72
# 250   1.0399   72
# 251   1.0271   74
#
# [252 rows x 2 columns]

# %%
df[['Density','Age','bodyfat']]
# Out:
#      Density  Age  bodyfat
# 0     1.0708   23     12.3
# 1     1.0853   22      6.1
# 2     1.0414   22     25.3
# 3     1.0751   26     10.4
# 4     1.0340   24     28.7
# ..       ...  ...      ...
# 247   1.0736   70     11.0
# 248   1.0236   72     33.6
# 249   1.0328   72     29.3
# 250   1.0399   72     26.0
# 251   1.0271   74     31.9
#
# [252 rows x 3 columns]

# %%
#adding new column:

# %%
df['Sport']='Kabaddi'
df.head()
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist    Sport
# 0  37.3   21.9    32.0     27.4   17.1  Kabaddi
# 1  37.3   23.4    30.5     28.9   18.2  Kabaddi
# 2  38.9   24.0    28.8     25.2   16.6  Kabaddi
# 3  37.3   22.8    32.4     29.4   18.2  Kabaddi
# 4  42.2   24.0    32.2     27.7   17.7  Kabaddi

# %%
#indexing loc,iloc:

# %%
df.iloc[0]
# Out:
# Density     1.0708
# bodyfat       12.3
# Age             23
# Weight      154.25
# Height       67.75
# Neck          36.2
# Chest         93.1
# Abdomen       85.2
# Hip           94.5
# Thigh           59
# Knee          37.3
# Ankle         21.9
# Biceps          32
# Forearm       27.4
# Wrist         17.1
# Sport      Kabaddi
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist    Sport
# 0  37.3   21.9    32.0     27.4   17.1  Kabaddi
# 1  37.3   23.4    30.5     28.9   18.2  Kabaddi
# 2  38.9   24.0    28.8     25.2   16.6  Kabaddi
# 3  37.3   22.8    32.4     29.4   18.2  Kabaddi

# %%
df.iloc[0:4,0:4]
# Out:
#    Density  bodyfat  Age  Weight
# 0   1.0708     12.3   23  154.25
# 1   1.0853      6.1   22  173.25
# 2   1.0414     25.3   22  154.00
# 3   1.0751     10.4   26  184.75

# %%
df.iloc[0:4,0:6:2]
# Out:
#    Density  Age  Height
# 0   1.0708   23   67.75
# 1   1.0853   22   72.25
# 2   1.0414   22   66.25
# 3   1.0751   26   72.25

# %%
df.iloc[0:10:2,0:8:2]
# Out:
#    Density  Age  Height  Chest
# 0   1.0708   23   67.75   93.1
# 2   1.0414   22   66.25   95.8
# 4   1.0340   24   71.25   97.3
# 6   1.0549   26   69.75  105.1
# 8   1.0900   25   74.00  100.9

# %%
df.iloc[0:100]['Density']
# Out:
# 0     1.0708
# 1     1.0853
# 2     1.0414
# 3     1.0751
# 4     1.0340
#        ...
# 95    1.0991
# 96    1.0770
# 97    1.0730
# 98    1.0582
# 99    1.0484
# Name: Density, Length: 100, dtype: float64

# %%
df.iloc[0:100][['Density','Age','bodyfat']]
# Out:
#     Density  Age  bodyfat
# 0    1.0708   23     12.3
# 1    1.0853   22      6.1
# 2    1.0414   22     25.3
# 3    1.0751   26     10.4
# 4    1.0340   24     28.7
# ..      ...  ...      ...
# 95   1.0991   53     17.4
# 96   1.0770   38      9.6
# 97   1.0730   50     11.3
# 98   1.0582   46     17.8
# 99   1.0484   47     22.2
#
# [100 rows x 3 columns]

# %%
#first 10 row and 1st 10 column:

# %%
df.iloc[:10,:10]
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1

# %%
df.iloc[300:,4:]
# Out:
# Empty DataFrame
# Columns: [Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist, Sport]
# Index: []

# %%
df.iloc[0][4]
# Out:
# 67.75

# %%
df.iloc[0][['Age','Density']]
# Out:
# Age            23
# Density    1.0708
# Name: 0, dtype: object

# %%
df.iloc[0]['Density']
# Out:
# 1.0708

# %%
df.iloc[0][4:8]
# Out:
# Height     67.75
# Neck        36.2
# Chest       93.1
# Abdomen     85.2
# Name: 0, dtype: object

# %%
#cheacking null value:

# %%
df.isnull()
# Out:
#      Density  bodyfat    Age  Weight  Height   Neck  Chest  Abdomen    Hip  \
# 0      False    False  False   False   False  False  False    False  False
# 1      False    False  False   False   False  False  False    False  False
# 2      False    False  False   False   False  False  False    False  False
# 3      False    False  False   False   False  False  False    False  False
# 4      False    False  False   False   False  False  False    False  False
# ..       ...      ...    ...     ...     ...    ...    ...      ...    ...
# 247    False    False  False   False   False  False  False    False  False
# 248    False    False  False   False   False  False  False    False  False
# 249    False    False  False   False   False  False  False    False  False
# 250    False    False  False   False   False  False  False    False  False
# 251    False    False  False   False   False  False  False    False  False
#
#      Thigh   Knee  Ankle  Biceps  Forearm  Wrist  Sport
# ...

# %%
df.isnull().sum()
# Out:
# Density    0
# bodyfat    0
# Age        0
# Weight     0
# Height     0
# Neck       0
# Chest      0
# Abdomen    0
# Hip        0
# Thigh      0
# Knee       0
# Ankle      0
# Biceps     0
# Forearm    0
# Wrist      0
# Sport      0
# dtype: int64

# %%
#Series related function:

# %%
df['Age'].sum()
# Out:
# 11311

# %%
df['Age'].max()
# Out:
# 81

# %%
df['Age'].min()
# Out:
# 22

# %%
df['Age'].std()
# Out:
# 12.602039722717866

# %%
#deletion operator:

# %%
df.drop(['Sport'],axis=1,inplace=True)
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
#filtering:

# %%
df[df['Age']>30]
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 12    1.0513     20.8   32  180.50   69.50  38.4  102.0     91.6  103.9
# 14    1.0484     22.1   35  187.75   69.50  40.5  101.3     96.4  100.1
# 15    1.0512     20.9   35  162.75   66.00  36.4   99.1     92.8   99.2
# 16    1.0333     29.0   34  195.75   71.00  38.9  101.9     96.4  105.2
# 17    1.0468     22.9   32  209.25   71.00  42.1  107.6     97.5  107.0
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 12    63.4  38.3   21.5    32.5     28.6   17.7
# ...

# %%
df[df['Age']<30]
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# 5     1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8
# 6     1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
# 7     1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1
# 8     1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9
# 9     1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1
# 10    1.0830      7.1   26  186.25   74.50  38.5  101.5     83.6   98.2
# 11    1.0812      7.8   27  216.00   76.00  39.4  103.6     90.9  107.7
# ...

# %%
df[df['Age']>30]['Density']
# Out:
# 12     1.0513
# 14     1.0484
# 15     1.0512
# 16     1.0333
# 17     1.0468
#         ...
# 247    1.0736
# 248    1.0236
# 249    1.0328
# 250    1.0399
# 251    1.0271
# Name: Density, Length: 214, dtype: float64

# %%
df[df['Age']>30][['Density','Weight']]
# Out:
#      Density  Weight
# 12    1.0513  180.50
# 14    1.0484  187.75
# 15    1.0512  162.75
# 16    1.0333  195.75
# 17    1.0468  209.25
# ..       ...     ...
# 247   1.0736  134.25
# 248   1.0236  201.00
# 249   1.0328  186.75
# 250   1.0399  190.75
# 251   1.0271  207.50
#
# [214 rows x 2 columns]

# %%
df[df['Age']>30][['Density','Weight','Height']]
# Out:
#      Density  Weight  Height
# 12    1.0513  180.50   69.50
# 14    1.0484  187.75   69.50
# 15    1.0512  162.75   66.00
# 16    1.0333  195.75   71.00
# 17    1.0468  209.25   71.00
# ..       ...     ...     ...
# 247   1.0736  134.25   67.00
# 248   1.0236  201.00   69.75
# 249   1.0328  186.75   66.00
# 250   1.0399  190.75   70.50
# 251   1.0271  207.50   70.00
#
# [214 rows x 3 columns]

# %%
df[df['Age']>30][['Density','Weight','Neck','Chest']]
# Out:
#      Density  Weight  Neck  Chest
# 12    1.0513  180.50  38.4  102.0
# 14    1.0484  187.75  40.5  101.3
# 15    1.0512  162.75  36.4   99.1
# 16    1.0333  195.75  38.9  101.9
# 17    1.0468  209.25  42.1  107.6
# ..       ...     ...   ...    ...
# 247   1.0736  134.25  34.9   89.2
# 248   1.0236  201.00  40.9  108.5
# 249   1.0328  186.75  38.9  111.1
# 250   1.0399  190.75  38.9  108.3
# 251   1.0271  207.50  40.8  112.4
#
# [214 rows x 4 columns]

# %%
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
sns.set(rc={'figure.figsize':(6,4)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-fb53a6da8be2> in <module>
# ----> 1 sns.set(rc={'figure.figsize':(6,4)})
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(10,15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-8b09f38ddb55> in <module>
# ----> 1 plt.figure(figsize=(10,15))
#
# NameError: name 'plt' is not defined

# %%
predict bodyfat given reset of values...predictive analysis

predict exercise routine based on bodyfat......feature engg

bmi column

# %%
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters  \
# ...

# %%
df['Weight_kg']=0.453592*df['Weight']
df.head()
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters        bmi
# 0  37.3   21.9    32.0     27.4   17.1  69.966566        1.72085  23.626779
# 1  37.3   23.4    30.5     28.9   18.2  78.584814        1.83515  23.334338
# 2  38.9   24.0    28.8     25.2   16.6  69.853168        1.68275  24.668737
# 3  37.3   22.8    32.4     29.4   18.2  83.801122        1.83515  24.883227
# 4  42.2   24.0    32.2     27.7   17.7  83.574326        1.80975  25.517358

# %%
df['Height_meters']=df['Height']*0.0254
df.head()
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters        bmi
# 0  37.3   21.9    32.0     27.4   17.1  69.966566        1.72085  23.626779
# 1  37.3   23.4    30.5     28.9   18.2  78.584814        1.83515  23.334338
# 2  38.9   24.0    28.8     25.2   16.6  69.853168        1.68275  24.668737
# 3  37.3   22.8    32.4     29.4   18.2  83.801122        1.83515  24.883227
# 4  42.2   24.0    32.2     27.7   17.7  83.574326        1.80975  25.517358

# %%
df['bmi']=df['Weight_kg']/(df['Height_meters']*df['Height_meters'])
df.head()
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters        bmi
# 0  37.3   21.9    32.0     27.4   17.1  69.966566        1.72085  23.626779
# 1  37.3   23.4    30.5     28.9   18.2  78.584814        1.83515  23.334338
# 2  38.9   24.0    28.8     25.2   16.6  69.853168        1.68275  24.668737
# 3  37.3   22.8    32.4     29.4   18.2  83.801122        1.83515  24.883227
# 4  42.2   24.0    32.2     27.7   17.7  83.574326        1.80975  25.517358

# %%
"""
BMI	Weight Status
Below 18.5	Underweight
18.5 – 24.9	Normal or Healthy Weight
25.0 – 29.9	Overweight
30.0 and Above	Obese
"""
# Out:
# '\nBMI\tWeight Status\nBelow 18.5\tUnderweight\n18.5 – 24.9\tNormal or Healthy Weight\n25.0 – 29.9\tOverweight\n30.0 and Above\tObese\n'

# %%
df['body_categories']:
# Out:
#   File "<ipython-input-15-aa24108f7752>", line 1
#     df['body_categories']:
#                           ^
# SyntaxError: invalid syntax

# %%
def get_bmi_categories(df):
    str_bmi_categories=''
    if df['bmi']<=18.5:
        str_bmi_categories='under weight'
    elif df['bmi']>18.5 and df['bmi']<=24.9:
        str_bmi_categories='normal weight'
    elif df['bmi']>25.0 and df['bmi']<=29.9:
        str_bmi_categories='over weight'
    else:
        str_bmi_categories='obese weight'
    return str_bmi_categories

# %%
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters  \
# ...

# %%
df['bmi_categories']=df.apply(get_bmi_categories,axis=1)

# %%
df.head(10)
# Out:
#    Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist  Weight_kg  Height_meters        bmi  \
# ...

# %%
# Out:
# 0      18.5_Underweight
# 1      18.5-24.9_Normal
# 2    25-29.9_Overweight
# 3            30.0_Obese
# dtype: category
# Categories (4, object): ['18.5-24.9_Normal', '18.5_Underweight', '25-29.9_Overweight', '30.0_Obese']
